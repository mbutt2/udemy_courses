# %%
import pandas as pd

# %%
df = pd.read_csv('udemy_courses.csv')

# %%
df.head(10)
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
# 1    1113822  ...  Business Finance
# 2    1006314  ...  Business Finance
# 3    1210588  ...  Business Finance
# 4    1011058  ...  Business Finance
# 5     192870  ...  Business Finance
# 6     739964  ...  Business Finance
# 7     403100  ...  Business Finance
# 8     476268  ...  Business Finance
# 9    1167710  ...  Business Finance
#
# [10 rows x 12 columns]

# %%
df['price'].head(15)
# showing the first 15 courses and their prices
# Out:
# 0     200
# 1      75
# 2      45
# 3      95
# 4     200
# 5     150
# 6      65
# 7      95
# 8     195
# 9     200
# 10    200
# 11    200
# 12     30
# 13    195
# 14    200
# Name: price, dtype: int64

# %%
df['price'].median()
# the median cost of the a Udemy course.
# Out:
# 45.0

# %%
df.median()
# looks through dataframe to find numeric values where it can get a median.
#  generally better because it isn't heavily affected by outliers like the mean will.
# Out:
# course_id           687917.0
# is_paid                  1.0
# price                   45.0
# num_subscribers        911.5
# num_reviews             18.0
# num_lectures            25.0
# content_duration         2.0
# dtype: float64

# %%
df.describe()
# gives a broad overview of some of the stats
# Out:
#           course_id        price  ...  num_lectures  content_duration
# count  3.678000e+03  3678.000000  ...   3678.000000       3678.000000
# mean   6.759720e+05    66.049483  ...     40.108755          4.094517
# std    3.432732e+05    61.005755  ...     50.383346          6.053840
# min    8.324000e+03     0.000000  ...      0.000000          0.000000
# 25%    4.076925e+05    20.000000  ...     15.000000          1.000000
# 50%    6.879170e+05    45.000000  ...     25.000000          2.000000
# 75%    9.613555e+05    95.000000  ...     45.750000          4.500000
# max    1.282064e+06   200.000000  ...    779.000000         78.500000
#
# [8 rows x 6 columns]

# %%
df['num_reviews'].count()
# matches above count value after using the describe method
# Out:
# 3678

# %%
df['is_paid'].value_counts()
# separates the count values for each.
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df['subject'].value_counts(normalize=True)
# to get the percentage value
# Out:
# Web Development        0.326264
# Business Finance       0.324905
# Musical Instruments    0.184883
# Graphic Design         0.163948
# Name: subject, dtype: float64

# %%
df[['course_title', 'is_paid', 'num_subscribers']].head(15).value_counts()
# groupby operation involves some combination of splitting up the object and then combining the results
# Out:
# course_title                                                  is_paid  num_subscribers
# Ultimate Investment Banking Course                            True     2147               1
# Trading Stock Chart Patterns For Immediate, Explosive Gains   True     2917               1
# Trading Penny Stocks: A Guide for All Levels In 2017          True     9221               1
# Trading Options With Money Flow                               True     1380               1
# The Only Investment Strategy You Need For Your Retirement     True     827                1
# Python Algo Trading: Sentiment Trading with News              True     294                1
# Options Trading 3 : Advanced Stock Profit and Success Method  True     5172               1
# Investing And Trading For Beginners: Mastering Price Charts   True     1540               1
# How To Maximize Your Profits Trading Options                  True     1276               1
# ...

# %%
subject_grp = df.groupby(['subject'])

# %%
subject_grp.get_group('Web Development')
# splitting up results by subject category of the course
# Out:
#       course_id  ...          subject
# 2478      28295  ...  Web Development
# 2479      19603  ...  Web Development
# 2480     889438  ...  Web Development
# 2481     197836  ...  Web Development
# 2482     505208  ...  Web Development
# ...         ...  ...              ...
# 3673     775618  ...  Web Development
# 3674    1088178  ...  Web Development
# 3675     635248  ...  Web Development
# 3676     905096  ...  Web Development
# 3677     297602  ...  Web Development
#
# [1200 rows x 12 columns]

# %%
filt = df['subject'] == 'Web Development'
df.loc[filt]['is_paid'].value_counts()
# if we're looking to get results on a single subject, it's very similar to before where we created a filter. 
# and then running the is_paid on the filter to see the value count of how many courses are charged and earning revenue
# Out:
# True     1067
# False     133
# Name: is_paid, dtype: int64

# %%
filt = df['subject'] == 'Business Finance'
df.loc[filt]['is_paid'].value_counts()
# changed it to Business Finance -- slightly more require $$
# Out:
# True     1099
# False      96
# Name: is_paid, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
filt = df['subject'] == 'Musical Instruments'
df.loc[filt]['is_paid'].value_counts()
# Out:
# True     634
# False     46
# Name: is_paid, dtype: int64

# %%
subject_grp['course_title'].value_counts().loc['Business Finance']
# Out:
# course_title
# CFA Level 2- Quantitative Methods                           2
# Essentials of money value: Get a financial Life !           2
# Introduction to Forex Trading Business For Beginners        2
# Understanding Financial Statements                          2
# 'Geometry Of Chance strategy of defeating the roulette."    1
#                                                            ..
# 株式投資に必要なスキルの学習手順を学ぶ                                         1
# 自分に合った投資信託を見つけよう！                                           1
# 資産運用の基礎を学ぶファイナンス入門                                          1
# 财务分析与估值建模入门                                                 1
# ６時間でインターバンク市場を攻略！最短距離でトレード基礎力                               1
# Name: course_title, Length: 1191, dtype: int64

# %%
subject_grp['price'].median()
# Out:
# subject
# Business Finance       45
# Graphic Design         30
# Musical Instruments    40
# Web Development        50
# Name: price, dtype: int64

# %%
subject_grp['price'].agg(['median', 'mean'])
# Out:
#                      median       mean
# subject
# Business Finance         45  68.552301
# Graphic Design           30  57.827529
# Musical Instruments      40  49.558824
# Web Development          50  77.033333

# %%
subject_grp['price'].agg(['median', 'mean']).loc['Business Finance']
# Out:
# median    45.000000
# mean      68.552301
# Name: Business Finance, dtype: float64

# %%
subject_grp['course_title'].str.contains('HTML5').sum()
# try using the apply method
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-23d583cecdd8> in <module>()
# ----> 1 subject_grp['course_title'].str.contains('HTML5').sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
filt = df['subject'] == 'Web Development'
df.loc[filt]['course_title'].str.contains('HTML5').sum()
# can use sum to count up TRUE value of booleans.

# %%
subject_grp['course_title'].apply(lambda x: x.str.contains('Excel').sum())
# returns the string values' appearance by group
# Out:
# subject
# Business Finance       25
# Graphic Design          1
# Musical Instruments     0
# Web Development         0
# Name: course_title, dtype: int64

# %%
subject_grp['course_title'].apply(lambda x: x.str.contains('Learn').sum())
# ie learn is a popular keyword for web development and musical instrument titles
# Out:
# subject
# Business Finance        94
# Graphic Design          68
# Musical Instruments    138
# Web Development        233
# Name: course_title, dtype: int64

# %%
df[['course_title', 'is_paid', 'num_subscribers','subject']]
# Out:
#                                            course_title  ...           subject
# 0                    Ultimate Investment Banking Course  ...  Business Finance
# 1     Complete GST Course & Certification - Grow You...  ...  Business Finance
# 2     Financial Modeling for Business Analysts and C...  ...  Business Finance
# 3     Beginner to Pro - Financial Analysis in Excel ...  ...  Business Finance
# 4          How To Maximize Your Profits Trading Options  ...  Business Finance
# ...                                                 ...  ...               ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...  ...   Web Development
# 3674  How To Design A WordPress Website With No Codi...  ...   Web Development
# 3675                      Learn and Build using Polymer  ...   Web Development
# 3676  CSS Animations: Create Amazing Effects on Your...  ...   Web Development
# 3677  Using MODX CMS to Build Websites: A Beginner's...  ...   Web Development
#
# [3678 rows x 4 columns]

# %%
subject_grp = df.groupby(['subject'])
subject_grp['course_title']

# %%
filt = df['is_paid'] == False
free_courses = df.loc[filt][['is_paid', 'course_title', 'subject','num_subscribers']].sort_values(by='num_subscribers', ascending = False)
top_rated = free_courses.groupby('subject')
top_rated.head(1)
# Out:
#       is_paid  ... num_subscribers
# 2827    False  ...          268923
# 1896    False  ...          101154
# 492     False  ...           65576
# 1461    False  ...           53851
#
# [4 rows x 4 columns]
